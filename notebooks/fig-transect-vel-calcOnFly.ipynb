# %%
import xarray as xr
from glob import glob
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, zoomed_inset_axes
import numpy as np
import cmocean.cm as cmo
from xgcm import Grid
import matplotlib.gridspec as gridspec

# %%
from distributed import Client, progress, LocalCluster
import socket

client = Client(service_kwargs={'dashboard': {'prefix': f'/node/{socket.gethostname()}/8787'}})
client
# Out:
# <Client: 'tcp://127.0.0.1:16425' processes=2 threads=2, memory=112.00 GiB>

# %%
def processROMSGrid(ds):
    ds = ds.rename({'eta_u': 'eta_rho', 'xi_v': 'xi_rho', 'xi_psi': 'xi_u', 'eta_psi': 'eta_v'})

    coords={'X':{'center':'xi_rho', 'inner':'xi_u'}, 
        'Y':{'center':'eta_rho', 'inner':'eta_v'}, 
        'Z':{'center':'s_rho', 'outer':'s_w'}}

    grid = Grid(ds, coords=coords, periodic=[])

    if ds.Vtransform == 1:
        Zo_rho = ds.hc * (ds.s_rho - ds.Cs_r) + ds.Cs_r * ds.h
        z_rho = Zo_rho + ds.zeta * (1 + Zo_rho/ds.h)
        Zo_w = ds.hc * (ds.s_w - ds.Cs_w) + ds.Cs_w * ds.h
        z_w = Zo_w + ds.zeta * (1 + Zo_w/ds.h)
    elif ds.Vtransform == 2:
        Zo_rho = (ds.hc * ds.s_rho + ds.Cs_r * ds.h) / (ds.hc + ds.h)
        z_rho = ds.zeta + (ds.zeta + ds.h) * Zo_rho
        Zo_w = (ds.hc * ds.s_w + ds.Cs_w * ds.h) / (ds.hc + ds.h)
        z_w = Zo_w * (ds.zeta + ds.h) + ds.zeta

    ds.coords['z_w'] = z_w.where(ds.mask_rho, 0).transpose('ocean_time', 's_w', 'eta_rho', 'xi_rho')
    ds.coords['z_rho'] = z_rho.where(ds.mask_rho, 0).transpose('ocean_time', 's_rho', 'eta_rho', 'xi_rho')
    # Other Option is to transpose arrays and fill NaNs with a minimal depth
    # ds['z_rho'] = z_rho.transpose(*('time', 's_rho','yh','xh'),transpose_coords=False).fillna(hmin)
    # ds['z_w'] = z_w.transpose(*('time', 's_w','yh','xh'),transpose_coords=False).fillna(hmin)
    ds.coords['z_rho0'] = z_rho.mean(dim='ocean_time')
    ds["z_rho0"] = ds.z_rho0.fillna(0)


     # interpolate depth of levels at U and V points
    ds['z_u'] = grid.interp(ds['z_rho'], 'X', boundary='fill')
    ds['z_v'] = grid.interp(ds['z_rho'], 'Y', boundary='fill')

    ds['pm_v'] = grid.interp(ds.pm, 'Y')
    ds['pn_u'] = grid.interp(ds.pn, 'X')
    ds['pm_u'] = grid.interp(ds.pm, 'X')
    ds['pn_v'] = grid.interp(ds.pn, 'Y')
    ds['pm_psi'] = grid.interp(grid.interp(ds.pm, 'Y'),  'X') # at psi points (eta_v, xi_u) 
    ds['pn_psi'] = grid.interp(grid.interp(ds.pn, 'X'),  'Y') # at psi points (eta_v, xi_u)

    ds['dx'] = 1/ds.pm
    ds['dx_u'] = 1/ds.pm_u
    ds['dx_v'] = 1/ds.pm_v
    ds['dx_psi'] = 1/ds.pm_psi

    ds['dy'] = 1/ds.pn
    ds['dy_u'] = 1/ds.pn_u
    ds['dy_v'] = 1/ds.pn_v
    ds['dy_psi'] = 1/ds.pn_psi

    ds['dz'] = grid.diff(ds.z_w, 'Z', boundary='fill')
    ds['dz_w'] = grid.diff(ds.z_rho, 'Z', boundary='fill')
    ds['dz_u'] = grid.interp(ds.dz, 'X')
    ds['dz_w_u'] = grid.interp(ds.dz_w, 'X')
    ds['dz_v'] = grid.interp(ds.dz, 'Y')
    ds['dz_w_v'] = grid.interp(ds.dz_w, 'Y')

    ds['dA'] = ds.dx * ds.dy

    return ds

def makeROMSGridObject(gridIn):
    gridOut = Grid(gridIn, 
    coords={'X':{'center':'xi_rho', 'inner':'xi_u'}, 
    'Y':{'center':'eta_rho', 'inner':'eta_v'}, 
    'Z':{'center':'s_rho', 'outer':'s_w'}},
    periodic=False, 
    metrics = {
        ('X',): ['dx', 'dx_u', 'dx_v', 'dx_psi'], # X distances
        ('Y',): ['dy', 'dy_u', 'dy_v', 'dy_psi'], # Y distances
        ('Z',): ['dz', 'dz_u', 'dz_v', 'dz_w', 'dz_w_u', 'dz_w_v'], # Z distances
        ('X', 'Y'): ['dA'] # Areas
    })
    return gridOut

# %%
def load_roms(filename,overlap):
    chunks = {'ocean_time': 1}
    glb_files = sorted(glob(filename))
    
    def preprocessRemoveOverlap(ds):
        '''remove the overlap from each file'''
        return ds.isel(ocean_time = slice(0,-overlap))

    for files in glb_files: 
        print(files)
        
    ds = xr.open_mfdataset(glb_files, chunks=chunks, preprocess=preprocessRemoveOverlap, data_vars='minimal', compat='override', coords='minimal', parallel=False, join='right')
    print('Loading data: OK!')
    return ds


# grid.transform(ds.temp.mean(dim='ocean_time'), 'Z', np.array([-500]),target_data=ds.z_rho0,method='linear').squeeze()

# %%
enoi = load_roms(filename='/srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04811.nc',overlap=19)
_4dvar = load_roms(filename='/srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04367.nc',overlap=7)
# Out:
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04811.nc
# Loading data: OK!
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04367.nc
# Loading data: OK!

# %%
enoi = processROMSGrid(enoi)
grid = makeROMSGridObject(enoi)

_4dvar = processROMSGrid(_4dvar)
grid_4dvar = makeROMSGridObject(_4dvar)

# %% [markdown]
# #### data prep

# %%
def process_trimVarsROMS(input,varsKeep):
    output_backup = input
    output = input[varsKeep]
    return output,output_backup


enoi = load_roms(filename='/srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_*.nc',overlap=19)
_4dvar = load_roms(filename='/srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_*.nc',overlap=7)

print('process grid')
enoi = processROMSGrid(enoi)
_4dvar = processROMSGrid(_4dvar)

print('drop almost all vars')
enoi,enoi_bu = process_trimVarsROMS(enoi,['v','z_rho0'])
_4dvar,_4dvar_bu = process_trimVarsROMS(_4dvar,['v','z_rho0'])
enoi = enoi.drop('z_rho')
_4dvar = _4dvar.drop('z_rho')



# print('subset dataset')
# enoi_28 = enoi.isel(eta_v=260)
# enoi_34 = enoi.isel(eta_v=115)

# _4dvar_28 = _4dvar.isel(eta_v=260)
# _4dvar_34 = _4dvar.isel(eta_v=115)
# Out:
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04371.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04375.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04379.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04383.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04387.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04391.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04395.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04399.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04403.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04407.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04411.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04415.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04419.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04423.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04427.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04431.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04435.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04439.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04443.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04447.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04451.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04455.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04459.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04463.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04467.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04471.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04475.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04479.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04483.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04487.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04491.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04495.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04499.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04503.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04507.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04511.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04515.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04519.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04523.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04527.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04531.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04535.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04539.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04543.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04547.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04551.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04555.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04559.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04563.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04567.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04571.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04575.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04579.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04583.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04587.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04591.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04595.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04599.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04603.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04607.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04611.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04615.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04619.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04623.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04627.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04631.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04635.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04639.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04643.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04647.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04651.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04655.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04659.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04663.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04667.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04671.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04675.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04679.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04683.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04687.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04691.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04695.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04699.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04703.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04707.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04711.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04715.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04719.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04723.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04727.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04731.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04735.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04739.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04743.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04747.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04751.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04755.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04759.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04763.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04767.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04771.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04775.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04779.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04783.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04787.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04791.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04795.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04799.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04803.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04807.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04811.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04815.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04819.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04823.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04827.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04831.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04835.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04839.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04843.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04847.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04851.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04855.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04859.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04863.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04867.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04871.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04875.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04879.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04883.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04887.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04891.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04895.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04899.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04903.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04907.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04911.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04915.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04919.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04923.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04927.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04931.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04935.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04939.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04943.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04947.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04951.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04955.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04959.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04963.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04967.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04971.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04975.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04979.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04983.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04987.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04991.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04995.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_04999.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05003.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05007.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05011.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05015.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05019.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05023.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05027.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05031.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05035.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05039.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05043.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05047.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05051.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05055.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05059.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05063.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05067.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05071.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05075.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05079.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05083.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05087.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05091.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05095.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05099.nc
# /srv/scratch/z3097808/forecasts_EnOI_TRADobs/output/eac_his_05103.nc
# Loading data: OK!
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04367.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04371.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04375.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04379.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04383.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04387.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04391.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04395.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04399.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04403.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04407.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04411.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04415.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04419.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04423.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04427.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04431.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04435.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04439.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04443.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04447.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04451.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04455.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04459.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04463.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04467.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04471.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04475.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04479.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04483.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04487.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04491.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04495.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04499.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04503.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04507.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04511.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04515.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04519.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04523.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04527.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04531.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04535.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04539.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04543.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04547.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04551.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04555.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04559.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04563.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04567.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04571.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04575.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04579.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04583.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04587.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04591.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04595.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04599.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04603.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04607.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04611.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04615.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04619.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04623.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04627.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04631.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04635.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04639.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04643.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04647.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04651.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04655.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04659.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04663.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04667.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04671.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04675.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04679.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04683.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04687.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04691.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04695.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04699.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04703.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04707.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04711.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04715.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04719.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04723.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04727.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04731.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04735.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04739.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04743.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04747.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04751.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04755.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04759.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04763.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04767.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04771.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04775.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04779.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04783.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04787.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04791.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04795.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04799.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04803.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04807.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04811.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04815.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04819.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04823.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04827.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04831.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04835.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04839.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04843.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04847.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04851.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04855.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04859.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04863.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04867.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04871.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04875.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04879.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04883.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04887.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04891.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04895.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04899.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04903.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04907.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04911.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04915.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04919.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04923.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04927.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04931.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04935.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04939.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04943.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04947.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04951.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04955.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04959.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04963.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04967.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04971.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04975.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04979.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04983.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04987.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04991.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04995.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_04999.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05003.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05007.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05011.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05015.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05019.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05023.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05027.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05031.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05035.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05039.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05043.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05047.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05051.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05055.nc
# /srv/scratch/z3533092/assimilation_newV2017_traditionalobs/ocean_fwd_001_05059.nc
# Loading data: OK!
# process grid
# drop almost all vars

# %%
enoi.to_netcdf('../data/proc/enoi_v.nc')
# Out:
# 2023-03-02 14:30:11,388 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2023-03-02 14:30:12,913 - distributed.nanny - WARNING - Restarting worker
#
# KeyboardInterrupt

# %%
# _4dvar.to_netcdf('../data/proc/4dvar_v.nc')

# %%
# STOP

# %%
print('subset dataset')
enoi_28 = enoi.isel(eta_v=260)
enoi_34 = enoi.isel(eta_v=115)

_4dvar_28 = _4dvar.isel(eta_v=260)
_4dvar_34 = _4dvar.isel(eta_v=115)

# %%
# STOP

# %%
enoi_28

# %%
enoi_28.to_netcdf('../data/proc/enoi_28.nc')

# %%
#### load datasets
print('load first transect')
print(enoi_28.nbytes/1e9)
enoi_28.load()
print('load second transect')
print(enoi_34.nbytes/1e9)
enoi_34.load()


enoi_28["z_rho0"] = enoi_28.z_rho0.fillna(0)
enoi_34["z_rho0"] = enoi_34.z_rho0.fillna(0)

#### load datasets
print('load first transect')
print(_4dvar_28.nbytes/1e9)
_4dvar_28.load()
print('load second transect')
print(_4dvar_34.nbytes/1e9)
_4dvar_34.load()


_4dvar_28["z_rho0"] = _4dvar_28.z_rho0.fillna(0)
_4dvar_34["z_rho0"] = _4dvar_34.z_rho0.fillna(0)

# %%
enoi_28

# %%
enoi_28.v.mean(dim='ocean_time').plot(y='z_rho0')
plt.show()
enoi_34.v.mean(dim='ocean_time').plot(y='z_rho0')

# %%
### filter singals

enoi_28_lp = enoi_28.v.rolling(ocean_time=12, center=True).mean()
enoi_28_hp = enoi_28.v - enoi_28_lp


enoi_34_lp = enoi_34.v.rolling(ocean_time=12, center=True).mean()
enoi_34_hp = enoi_34.v - enoi_34_lp



_4dvar_28_lp = enoi_28.v.rolling(ocean_time=12, center=True).mean()
_4dvar_28_hp = enoi_28.v - _4dvar_28_lp


_4dvar_34_lp = _4dvar_34.v.rolling(ocean_time=12, center=True).mean()
_4dvar_34_hp = _4dvar_34.v - _4dvar_34_lp

# %%
def addSubplot_spatialMap(input,pcol_kwargs={}, cont_kwargs={}, kde_kwargs={}):
    ax.set_extent([148, 161, -42, -25])
    feature = ax.add_feature(Coast, edgecolor='black',facecolor='gray')
    im = ax.pcolormesh(input.lon_rho,input.lat_rho,input,**pcol_kwargs)   
    gl = ax.gridlines(draw_labels=True,
                     color='black', alpha=0.2, linestyle='--')
    gl.right_labels = False
    gl.top_labels = False
    gl.left_labels = False
    gl.bottom_labels = False
    ax.set_title('')
    return gl,im



def addInsetColormap(ax,im,lab):
    cax = inset_axes(ax,
                width="5%",  # width = 10% of parent_bbox width
                height="50%",  # height : 50%
                loc='lower left',
                bbox_to_anchor=(.03,.39, 1, 1),
                bbox_transform=ax.transAxes,
                borderpad=0,
                )
    cbar = fig.colorbar(im, cax=cax) 
    cbar.set_label(lab)


# gs to make a 4 row, 7 col plot

plt.cla()
plt.clf()
fig = plt.figure(figsize=[11,11],dpi=150)
ax = None

gs = fig.add_gridspec(nrows=4,ncols=4,wspace=0.05, hspace=0.05)

# gs00 = gs0[0].subgridspec(2, 2,wspace=0.05, hspace=0.05)
# gs01 = gs0[1].subgridspec(1, 1)

cax_mn = (2,20)
cax_std = (0,1)
cax_std_hp = (0,1)
cax_std_lp = (0,1)


###############
ax = fig.add_subplot(gs[0,0])
_4dvar_28.v.mean(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=-1,vmax=1)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'a', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.4, -.5, '28$\circ$S',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, '4D-Var',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[0,1])
_4dvar_28.v.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'b', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)


ax = fig.add_subplot(gs[0,2])
_4dvar_28_hp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'c', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[0,3])
_4dvar_28_lp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'd', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)



###############
ax = fig.add_subplot(gs[1,0])
enoi_28.v.mean(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=-1,vmax=1)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'e', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[1,1])
enoi_28.v.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'f', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)


ax = fig.add_subplot(gs[1,2])
enoi_28_hp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'g', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[1,3])
enoi_28_lp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'h', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)




##############
ax = fig.add_subplot(gs[2,0])
_4dvar_34.v.mean(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=-1,vmax=1)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'i', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.4, -.5, '34$\circ$S',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, '4D-Var',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[2,1])
_4dvar_34.v.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'j', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[2,2])
_4dvar_34_hp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'k', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[2,3])
_4dvar_34_lp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'l', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)







##############
ax = fig.add_subplot(gs[3,0])
enoi_34.v.mean(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=-1,vmax=1)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'm', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[3,1])
enoi_34.v.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'n', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[3,2])
enoi_34_hp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'o', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[3,3])
enoi_34_lp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'p', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

# %%
def addSubplot_spatialMap(input,pcol_kwargs={}, cont_kwargs={}, kde_kwargs={}):
    ax.set_extent([148, 161, -42, -25])
    feature = ax.add_feature(Coast, edgecolor='black',facecolor='gray')
    im = ax.pcolormesh(input.lon_rho,input.lat_rho,input,**pcol_kwargs)   
    gl = ax.gridlines(draw_labels=True,
                     color='black', alpha=0.2, linestyle='--')
    gl.right_labels = False
    gl.top_labels = False
    gl.left_labels = False
    gl.bottom_labels = False
    ax.set_title('')
    return gl,im



def addInsetColormap(ax,im,lab):
    cax = inset_axes(ax,
                width="5%",  # width = 10% of parent_bbox width
                height="50%",  # height : 50%
                loc='lower left',
                bbox_to_anchor=(.03,.39, 1, 1),
                bbox_transform=ax.transAxes,
                borderpad=0,
                )
    cbar = fig.colorbar(im, cax=cax) 
    cbar.set_label(lab)


# gs to make a 4 row, 7 col plot

plt.cla()
plt.clf()
fig = plt.figure(figsize=[11,11],dpi=150)
ax = None

gs = fig.add_gridspec(nrows=4,ncols=4,wspace=0.05, hspace=0.05)

# gs00 = gs0[0].subgridspec(2, 2,wspace=0.05, hspace=0.05)
# gs01 = gs0[1].subgridspec(1, 1)

cax_mn = (2,20)
cax_std = (0,1)
cax_std_hp = (0,1)
cax_std_lp = (0,1)


###############
ax = fig.add_subplot(gs[0,0])
_4dvar_28.v.mean(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=5,vmax=25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'a', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.4, -.5, '28$\circ$S',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, '4D-Var',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[0,1])
_4dvar_28.v.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'b', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)


ax = fig.add_subplot(gs[0,2])
_4dvar_28_hp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'c', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[0,3])
_4dvar_28_lp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'd', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)





###############
ax = fig.add_subplot(gs[1,0])
enoi_28.v.mean(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=5,vmax=25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'e', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[1,1])
enoi_28.v.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'f', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)


ax = fig.add_subplot(gs[1,2])
enoi_28_hp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'g', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[1,3])
enoi_28_lp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'h', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)



###############
ax = fig.add_subplot(gs[2,0])
(_4dvar_28.v.mean(dim='ocean_time')-enoi_28.temp.mean(dim='ocean_time')).plot(x='lon_rho',y='z_rho0',cmap='cmo.balance',vmin=-2,vmax=2)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'e', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, '4DVar-EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[2,1])
(_4dvar_28.v.std(dim='ocean_time')-enoi_28.temp.std(dim='ocean_time')).plot(x='lon_rho',y='z_rho0',cmap='cmo.balance',vmin=-0.1,vmax=.1)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'f', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)


ax = fig.add_subplot(gs[2,2])
(_4dvar_28_hp.std(dim='ocean_time')-enoi_28_hp.std(dim='ocean_time')).plot(x='lon_rho',y='z_rho0',cmap='cmo.balance',vmin=-0.1,vmax=.1)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'g', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[2,3])
(_4dvar_28_lp.std(dim='ocean_time')-enoi_28_lp.std(dim='ocean_time')).plot(x='lon_rho',y='z_rho0',cmap='cmo.balance',vmin=-.1,vmax=.1)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'h', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)


##############
ax = fig.add_subplot(gs[3,0])
_4dvar_34.v.mean(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=5,vmax=25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'i', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.4, -.5, '34$\circ$S',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, '4D-Var',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[3,1])
_4dvar_34.v.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'j', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[3,2])
_4dvar_34_hp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'k', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[3,3])
_4dvar_34_lp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'l', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)







##############
ax = fig.add_subplot(gs[4,0])
enoi_34.v.mean(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=5,vmax=25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'm', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[4,1])
enoi_34.v.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'n', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[4,2])
enoi_34_hp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'o', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[4,3])
enoi_34_lp.std(dim='ocean_time').plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'p', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)



##############
ax = fig.add_subplot(gs[5,0])
(_4dvar_34.v.mean(dim='ocean_time')-enoi_34.temp.mean(dim='ocean_time')).plot(x='lon_rho',y='z_rho0',cmap='cmo.curl',vmin=5,vmax=25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('Depth (m)')
ax.text(0.01, 0.99, 'm', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Mean',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[5,1])
(_4dvar_34.v.std(dim='ocean_time')-enoi_34.temp.std(dim='ocean_time')).plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'n', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev.',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[5,2])
(_4dvar_34_hp.std(dim='ocean_time')-enoi_34_hp.std(dim='ocean_time')).plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=.25)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'o', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (HP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)

ax = fig.add_subplot(gs[5,3])
(_4dvar_34_lp.std(dim='ocean_time')-enoi_34_lp.std(dim='ocean_time')).plot(x='lon_rho',y='z_rho0',cmap='cmo.amp',vmin=0,vmax=2.5)#,pcol_kwargs={'cmap':'cmo.balance','vmin':-1e-4*scaling,'vmax':1e-4*scaling})
ax.set_ylabel('')
ax.set_yticklabels([])
ax.text(0.01, 0.99, 'p', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
# ax.text(0.5, 1.12, 'Std Dev. (LP)',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
# ax.text(-.26, .5, 'EnOI',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)
# Out:
# 2023-03-02 14:30:13,751 - distributed.nanny - WARNING - Restarting worker
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/distributed/__init__.py", line 15, in <module>
#     from distributed.actor import Actor, ActorFuture, BaseActorFuture
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/distributed/actor.py", line 14, in <module>
#     from distributed.client import Future
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/distributed/client.py", line 54, in <module>
#     from distributed import cluster_dump, preloading
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/distributed/preloading.py", line 19, in <module>
#     from distributed.core import Server
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/distributed/core.py", line 28, in <module>
#     from distributed.comm import (
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/distributed/comm/__init__.py", line 16, in <module>
#     from distributed.comm.utils import get_tcp_server_address, get_tcp_server_addresses
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/distributed/comm/utils.py", line 29, in <module>
#     import numpy
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/numpy/__init__.py", line 345, in <module>
#     _sanity_check()
#   File "/home/z3533092/miniconda3/envs/devel3.9/lib/python3.9/site-packages/numpy/__init__.py", line 335, in _sanity_check
#     if not abs(x.dot(x) - 2.0) < 1e-5:
# KeyboardInterrupt
# 2023-03-02 14:30:13,816 - distributed.nanny - WARNING - Restarting worker

# %%
STOP

# %%
u_bar = grid.interp(enoi.u.mean("ocean_time"),'X')
v_bar = grid.interp(enoi.v.mean("ocean_time"),'Y')
mke = 0.5*(u_bar**2 + v_bar**2)

enoi["mke"] = mke

# %%
enoi.mke.isel(s_rho=-1).plot()

# %%
u_rho = grid.interp(enoi.u,'X')
v_rho = grid.interp(enoi.v,'Y')

print('calc velocity anomalies')
u_prime = u_rho - u_bar
v_prime = v_rho - v_bar

print('calc eke')
eke = 0.5*(u_prime**2 + v_prime**2)

# enoi["eke"] = eke

# %%
eke.isel(s_rho=-1).mean(dim='ocean_time').plot()

# %%
eke_0_400=grid.average(eke.where(enoi.z_rho>-400),'Z')
# eke_0_400=grid.average(eke.where(enoi.z_rho>-400),'Z')
mke_0_400=mke.where(enoi.z_rho0>-400).weighted(weights=enoi.dz.mean(dim='ocean_time')).mean(dim='s_rho')

eke_400_1200=grid.average(eke.where((enoi.z_rho<-400)&(enoi.z_rho>-1200)),'Z')
# mke_400_1200=grid.average(mke.where((enoi.z_rho0<-400)&(enoi.z_rho0>-1200)),'Z')
mke_400_1200=mke.where((enoi.z_rho0<-400)&(enoi.z_rho0>-1200)).weighted(weights=enoi.dz.mean(dim='ocean_time')).mean(dim='s_rho')

# %%
eke_0_400.mean(dim='ocean_time').plot()

# %%
(eke.where(enoi.z_rho>-400).weighted(weights=enoi.dz).mean(dim='s_rho').mean(dim='ocean_time')).plot()

# %% [markdown]
# #### Start plotting

# %%
Coast = cfeature.NaturalEarthFeature(category='physical', scale='10m',
                            facecolor='none', name='coastline')
CoastHR = cfeature.GSHHSFeature(scale='auto')

# %%
def addSubplot_spatialMap(input,Grid,pcol_kwargs={}, cont_kwargs={}, kde_kwargs={}):
    ax.set_extent([148, 161, -42, -25])
    feature = ax.add_feature(Coast, edgecolor='black',facecolor='gray')
    im = ax.pcolormesh(Grid.lon_rho,Grid.lat_rho,input,**pcol_kwargs)   
    gl = ax.gridlines(draw_labels=True,
                     color='black', alpha=0.2, linestyle='--')
    gl.right_labels = False
    gl.top_labels = False
    gl.left_labels = False
    gl.bottom_labels = False
    ax.set_title('')
    return gl,im



# gs to make a 4 row, 7 col plot
gs = gridspec.GridSpec(nrows=2,ncols=5,wspace=0.05, hspace=0.05)
plt.cla()
plt.clf()
fig = plt.figure(figsize=[17,9])
ax = None


ax = fig.add_subplot(gs[0,0], projection=ccrs.PlateCarree())
gl,im=addSubplot_spatialMap(mke_0_400,enoi)
# co = truth_eke_0.std(dim='ocean_time').plot.contour(ax=ax[0], x='lon_rho',y='lat_rho',levels=np.arange(0,0.4,0.1),colors='black',zorder=12, linewidths=0.5)
# ax[0].clabel(co, co.levels, inline=True, fontsize=10)
gl.left_labels = True
ax.text(0.01, 0.99, 'a', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax = fig.add_subplot(gs[0,1], projection=ccrs.PlateCarree())
gl,im=addSubplot_spatialMap(mke_400_1200,enoi)
ax.text(0.01, 0.99, 'b', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax = fig.add_subplot(gs[0,2], projection=ccrs.PlateCarree())
gl,im=addSubplot_spatialMap(eke_0_400.mean(dim='ocean_time'),enoi)
ax.text(0.01, 0.99, 'c', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')
ax = fig.add_subplot(gs[0,3], projection=ccrs.PlateCarree())
gl,im=addSubplot_spatialMap(eke_400_1200.mean(dim='ocean_time'),enoi)
ax.text(0.01, 0.99, 'd', transform=ax.transAxes,fontsize=22, fontweight='bold', va='top')

# ax.text(-.26, .5, 'EKE (0 m) & RMSE',fontsize=14, rotation='vertical', fontweight='bold', va='center', ha='center', transform=ax.transAxes)
# ax.text(0.5, 1.12, 'Ref state',fontsize=14, fontweight='bold', va='top', ha='center', transform=ax.transAxes)
